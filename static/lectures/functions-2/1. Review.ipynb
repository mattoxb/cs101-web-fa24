# %% [markdown]
# ## A Quick Review
#
# Take a look at the following function.
# - What are the names of the parameters?
# - Does it create any local variables?
# - Does it access any global variables?
# - What does it actually do?

# %%
semester = 'Spring 2024'
positions = 1

def welcome(name):
    positions = 10
    print(f'Welcome to {semester}.  There are {x} positions available.')

# %%
welcome('Henry')

# %% [markdown]
# ## Exercise
#
# Create a function `checkout` that takes a list of prices, adds them all up, and then adds a sales tax.  The tax should be a keyword argument defaulting to 10%.
