# %% [markdown]
# ## Bugs that Make Your Program Not Even Run

# %% [markdown]
# ### Example 1.1

# %%
def average(xx):
    for x in xx:
        a = a + x
    return a / len(xx)

# %%
average([1,2,3])

# %% [markdown]
# ### Example 1.2

# %%
a = math.sqrt(b * b + c * c)

# %% [markdown]
# ### Example 1.3

# %%
a = (b * b + c * c) ** -.5

# %% [markdown]
# ### Example 1.4

# %%
def average(xx):
    a = 0
    for x in xx:
        a = a + x
   return a / len(xx)

# %% [markdown]
# ### Example 1.5

# %%
def average(xx):
    a = 0
    for x in xx
        a = a + x
    return a / len(xx)

# %% [markdown]
# ### Discussion
#
# Most of theses errors are what we call *syntax errors*.

# %% [markdown]
# ### Fix 1.1

# %% [markdown]
# ### Fix 1.2

# %% [markdown]
# ### Fix 1.3

# %% [markdown]
# ### Fix 1.4

# %% [markdown]
# ### Fix 1.5
