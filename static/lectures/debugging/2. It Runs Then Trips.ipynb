# %% [markdown]
# ## It Runs.  Then trips....

# %% [markdown]
# ### Example 2.1

# %%
pb = { 'Emergency': 911, 'Jenny': 8675309 }

# %%
mattoxPhoneNumber = pb['Mattox']

# %% [markdown]
# ### Example 2.2

# %%
primes = [2,3,5,7]

# %%
primes[5]

# %% [markdown]
# ### Example 2.3

# %%
age = input("How old are you? ")
print(f"Next year you will be {age + 1}")

# %% [markdown]
# ### Discussion
#
# - In these cases the program tried to do something it wasn't supposed to do.
# - You can check the program to be sure you didn't ask something impossible....
# - Or you can have the program check for you!

# %% [markdown]
# ### Fix 2.1

# %% [markdown]
# ### Fix 2.2

# %% [markdown]
# ### Fix 2.3
