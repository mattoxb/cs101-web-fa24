# %% [markdown]
# ## It Runs, but Doesn't Work!

# %%
def stdev(xx):
    sum = 0
    for x in xx:
        sum = sum + x
    mu = x / len(xx)
    dev = 0
    for x in xx:
        dev = dev + (x - mu) * 2
    return dev ** 0.5 / mu

# %%
stdev([2,3,4])

# %% [markdown]
# ### Step 1: Be very clear what you expect your program to do.
#
# - The best way to do this is to have some inputs and expected outputs.
# - A pseducode version can also be very useful.
# - Can you do the requested calculation yourself, by hand?
# - Are you assuming anything about the data?
# - Let's try an example!

# %% [markdown]
# ## Step 2: If it makes sense, it's nice to make a testing function.

# %%
def testStdev():
    xx = [2,3,4]
    ans = stdev(xx)
    # What comes next?

# %% [markdown]
# ## Step 3: Use print statements to see what's going on!
# - You can also make a simpler version of the program to test!  You could break this program into two parts so you can test them individually.

# %%
def stdev(xx):
    sum = 0
    for x in xx:
        sum = sum + x
    mu = x / len(xx)
    dev = 0
    for x in xx:
        dev = dev + (x - mu) * 2
    return dev ** 0.5 / mu
