# %% [markdown]
# ## Writing to files
#
# - The syntax `open(fname,'w')` says we want to **write** to a file.
#   - The file is created if it doesn't already exist.
#   - The file is **destroyed** if it already does!

# %%
# Demo: Write the odd numbers between 0 to 100 to a files called `odds.txt`.
## Do you remember how `range` works?

# %%
with open('odds.txt','w') as file:
    pass

# %%
# Look at the file to see what's in it.  What went wrong?

# %%
with open('odds.txt') as file:
    print(file.readlines())

# %% [markdown]
# ## Your turn!
#
# - Write a program that will read in the `data2.txt` file, add 10 to every integer element, and write it back **to the same file**.
# - If you mess up, there's a `data2-backup.txt` that you can use to refresh the original.

# %%
# Your code here!
