# %% [markdown]
# ## Processing Data
#
# - The `strip` command removes trailing whitespace.

# %%
# Remember what happened here.  Why are there extra lines?
with open('fear.txt') as file:
    num = 1
    for row in file.readlines():
        print(f"{num}: {row}")  # Do you remember format strings?
        num += 1

# %%
"   hello!  \n".strip()

# %%
# How can use `strip` to clean this up?
with open('fear.txt') as file:
    num = 1
    for row in file.readlines():
        print(f"{num}: {row}")  # Do you remember format strings?
        num += 1

# %% [markdown]
# ## Demo
#
# - We want to read the data in `data1.txt` and process the numbers.
#   - Open the file and return the count and average of the numbers.

# %%
with open('data1.txt') as data:
    # instructor will put code here
    pass

# %% [markdown]
# ## Demo 2
# - We want to read the data in data2.txt.
# - Step 1: read it all in, and take the average of the integer part of the data.

# %%
# hint:
"a,10".split(',')

# %%
with open('data2.txt') as data:
    pass

# %% [markdown]
# - Step 2: read it in, but only process the pairs with a specific first element.

# %%
def process(letter):
    with open('data2.txt') as data:
        pass
