# %% [markdown]
# # Python Files!
# ## Today's Objectives
# - Open a file using the `open` command and ...
#   - read the contents
#   - process the contents into Python datatypes
#   - write to a new file
#
# ## Order
# - [Reading Files](1.%20Reading%20Files.ipynb)
# - [Processing File Data](2.%20Processing%20File%20Data.ipynb)
# - [Writing Files](3.%20Writing%20Files.ipynb)
#
# ## Announcements
# - Midterm 1 is live!  Good luck!
# - The first homework will go live **this Friday**
# -
