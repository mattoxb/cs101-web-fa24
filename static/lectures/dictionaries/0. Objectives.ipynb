# %% [markdown]
# # Python Dictionaries!
#
# If you have lists and dictionaries, you can do pretty much anything.
#
# ## Today's Objectives
# - Explain what we mean by dictionary in the context of Python
# - Show two ways of creating a dictionary.
# - Look up and delete information from a dictionary.
# - Rick-roll pesty people by giving them a fake phone number.
#
# ## Order
# - [Creating Dictionaries](1.%20Creating%20Dictionaries.ipynb)
# - [Looking Up](2.%20Looking%20Up.ipynb)
# - [Inverting](3.%20Inverting.ipynb)
#
# ## Announcements!
# - HW 1 is live.  HW 2 will be released this Friday.
# ## Pro Tip!
