# %% [markdown]
# ## Inverting Dictionaries
#
# - We want to make a reverse phone number lookup table.
# - Work with a friend to see if you can do it.  Here's some starter code and the old phone number dictionary.

# %%
pb = {'Empire': '588-2300', 'Emergency': '911', 'Jenny': '867-5309'}

# %%
def reverse(old):
    "Returns a new dictionary where the keys and values are reversed."
    new = {}
    return new

# %%
# Tests
rpb = reverse(pb)
for v in pb.values():
    if pb[rpb[v]] == v:
        print(f"Value {v} found.")
