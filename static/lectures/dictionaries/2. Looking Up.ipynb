# %% [markdown]
# ## Looking Things Up

# %%
org = { 'Frodo': {'job':'Hold Ring', 'salary': 15000}
      , 'Sam': {'job':'Gardener', 'salary': 200000}
      , 'Gollum': {'job':'Pest', 'salary': 0}
      , 'Pi': 3.14159}

# %%
pb = {'Empire': '588-2300', 'Emergency': '911', 'Jenny': '867-5309'}

# %%
org['Sam']

# %%
org['Sam']['salary']

# %%
def rickRoll(pb,name):
  pb[name] = "248-434-5508"
  return pb

# %%
## Your turn.  Write a function `salary` that takes an org chart and a name and returns their salary.
def salary():
    pass
